# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('mushrooms.csv')
df.head().T
# Out:
#                           0  1  2  3  4
# class                     p  e  e  p  e
# cap-shape                 x  x  b  x  x
# cap-surface               s  s  s  y  s
# cap-color                 n  y  w  w  g
# bruises                   t  t  t  t  f
# odor                      p  a  l  p  n
# gill-attachment           f  f  f  f  f
# gill-spacing              c  c  c  c  w
# gill-size                 n  b  b  n  b
# gill-color                k  k  n  n  k
# stalk-shape               e  e  e  e  t
# stalk-root                e  c  c  e  e
# stalk-surface-above-ring  s  s  s  s  s
# stalk-surface-below-ring  s  s  s  s  s
# stalk-color-above-ring    w  w  w  w  w
# stalk-color-below-ring    w  w  w  w  w
# veil-type                 p  p  p  p  p
# veil-color                w  w  w  w  w
# ring-number               o  o  o  o  o
# ring-type                 p  p  p  p  e
# spore-print-color         k  n  n  k  n
# population                s  n  n  s  a
# habitat                   u  g  m  u  g

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
df.dtypes
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %%
def unique_values(columns):
    for column in columns:
        print(f"{column} : {df[column].unique()}")
unique_values(df.columns)
# Out:
# class : ['p' 'e']
# cap-shape : ['x' 'b' 's' 'f' 'k' 'c']
# cap-surface : ['s' 'y' 'f' 'g']
# cap-color : ['n' 'y' 'w' 'g' 'e' 'p' 'b' 'u' 'c' 'r']
# bruises : ['t' 'f']
# odor : ['p' 'a' 'l' 'n' 'f' 'c' 'y' 's' 'm']
# gill-attachment : ['f' 'a']
# gill-spacing : ['c' 'w']
# gill-size : ['n' 'b']
# gill-color : ['k' 'n' 'g' 'p' 'w' 'h' 'u' 'e' 'b' 'r' 'y' 'o']
# stalk-shape : ['e' 't']
# stalk-root : ['e' 'c' 'b' 'r' '?']
# stalk-surface-above-ring : ['s' 'f' 'k' 'y']
# stalk-surface-below-ring : ['s' 'f' 'y' 'k']
# stalk-color-above-ring : ['w' 'g' 'p' 'n' 'b' 'e' 'o' 'c' 'y']
# stalk-color-below-ring : ['w' 'p' 'g' 'b' 'n' 'e' 'y' 'o' 'c']
# veil-type : ['p']
# veil-color : ['w' 'n' 'o' 'y']
# ring-number : ['o' 't' 'n']
# ring-type : ['p' 'e' 'l' 'f' 'n']
# spore-print-color : ['k' 'n' 'u' 'h' 'w' 'r' 'o' 'y' 'b']
# population : ['s' 'n' 'a' 'v' 'y' 'c']
# habitat : ['u' 'g' 'm' 'd' 'p' 'w' 'l']

# %%
from sklearn.preprocessing import LabelEncoder
encoded = LabelEncoder()
def encoder():
    for column in df.columns:
        df[column] = encoded.fit_transform(df[[column]])

# %%
encoder()

# %%
df.head().T
# Out:
#                           0  1  2  3  4
# class                     1  0  0  1  0
# cap-shape                 5  5  0  5  5
# cap-surface               2  2  2  3  2
# cap-color                 4  9  8  8  3
# bruises                   1  1  1  1  0
# odor                      6  0  3  6  5
# gill-attachment           1  1  1  1  1
# gill-spacing              0  0  0  0  1
# gill-size                 1  0  0  1  0
# gill-color                4  4  5  5  4
# stalk-shape               0  0  0  0  1
# stalk-root                3  2  2  3  3
# stalk-surface-above-ring  2  2  2  2  2
# stalk-surface-below-ring  2  2  2  2  2
# stalk-color-above-ring    7  7  7  7  7
# stalk-color-below-ring    7  7  7  7  7
# veil-type                 0  0  0  0  0
# veil-color                2  2  2  2  2
# ring-number               1  1  1  1  1
# ring-type                 4  4  4  4  0
# spore-print-color         2  3  3  2  3
# population                3  2  2  3  0
# habitat                   5  1  3  5  1

# %%
unique_values(df.columns)
# Out:
# class : [1 0]
# cap-shape : [5 0 4 2 3 1]
# cap-surface : [2 3 0 1]
# cap-color : [4 9 8 3 2 5 0 7 1 6]
# bruises : [1 0]
# odor : [6 0 3 5 2 1 8 7 4]
# gill-attachment : [1 0]
# gill-spacing : [0 1]
# gill-size : [1 0]
# gill-color : [ 4  5  2  7 10  3  9  1  0  8 11  6]
# stalk-shape : [0 1]
# stalk-root : [3 2 1 4 0]
# stalk-surface-above-ring : [2 0 1 3]
# stalk-surface-below-ring : [2 0 3 1]
# stalk-color-above-ring : [7 3 6 4 0 2 5 1 8]
# stalk-color-below-ring : [7 6 3 0 4 2 8 5 1]
# veil-type : [0]
# veil-color : [2 0 1 3]
# ring-number : [1 2 0]
# ring-type : [4 0 2 1 3]
# spore-print-color : [2 3 6 1 7 5 4 8 0]
# population : [3 2 0 4 5 1]
# habitat : [5 1 3 0 4 6 2]

# %%
x = df.drop('class', axis=1)
y = df['class']

# %%
x.head().T
# Out:
#                           0  1  2  3  4
# cap-shape                 5  5  0  5  5
# cap-surface               2  2  2  3  2
# cap-color                 4  9  8  8  3
# bruises                   1  1  1  1  0
# odor                      6  0  3  6  5
# gill-attachment           1  1  1  1  1
# gill-spacing              0  0  0  0  1
# gill-size                 1  0  0  1  0
# gill-color                4  4  5  5  4
# stalk-shape               0  0  0  0  1
# stalk-root                3  2  2  3  3
# stalk-surface-above-ring  2  2  2  2  2
# stalk-surface-below-ring  2  2  2  2  2
# stalk-color-above-ring    7  7  7  7  7
# stalk-color-below-ring    7  7  7  7  7
# veil-type                 0  0  0  0  0
# veil-color                2  2  2  2  2
# ring-number               1  1  1  1  1
# ring-type                 4  4  4  4  0
# spore-print-color         2  3  3  2  3
# population                3  2  2  3  0
# habitat                   5  1  3  5  1

# %%
y
# Out:
# 0       1
# 1       0
# 2       0
# 3       1
# 4       0
#        ..
# 8119    0
# 8120    0
# 8121    0
# 8122    1
# 8123    0
# Name: class, Length: 8124, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)
x_train.shape, y_train.shape
# Out:
# ((5686, 22), (5686,))

# %%
from sklearn.linear_model import LogisticRegression
classifier = LogisticRegression()
classifier
# Out:
# LogisticRegression()

# %%
classifier.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
classifier.coef_
# Out:
# array([[-0.01993988,  0.45304873, -0.07080096, -0.97133702, -0.55645481,
#         -1.22552476, -6.73259364,  7.11312226, -0.13410774,  0.31275469,
#         -1.5473676 , -4.32825311, -0.28885274, -0.14579722, -0.04544451,
#          0.        ,  5.19830956,  1.45236874,  0.87315025, -0.21039311,
#         -0.36827736,  0.07937545]])

# %%
classifier.intercept_
# Out:
# array([0.90437251])

# %%
y_predicted = classifier.predict(x_test)
y_predicted
# Out:
# array([0, 0, 1, ..., 0, 0, 1])

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %%
def metrics(y_test, y_pred):
    print(f"Classifiction Reoport : \n{classification_report(y_test, y_pred)}\n")
    print(f"Accuracy Score : \t{accuracy_score(y_test, y_pred) * 100}\n")
    print(f"Confusion Matrix : \n{confusion_matrix(y_test, y_pred)}")

# %%
metrics(y_test, y_predicted)
# Out:
# Classifiction Reoport :
#               precision    recall  f1-score   support
#
#            0       0.94      0.96      0.95      1236
#            1       0.96      0.94      0.95      1202
#
#     accuracy                           0.95      2438
#    macro avg       0.95      0.95      0.95      2438
# weighted avg       0.95      0.95      0.95      2438
#
#
# Accuracy Score : 	94.99589827727645
#
# Confusion Matrix :
# [[1190   46]
#  [  76 1126]]

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters = {
    "penalty" : ['l1', 'l2', 'elasticnet'],
    "C" : [19.99,19.999,19.995],
    "solver" : ['lbfgs', 'newton-cg', 'sag', 'saga']
}

# %%
grid = GridSearchCV(estimator=classifier, param_grid=parameters, cv=5, verbose=3)
grid
# Out:
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [19.99, 19.999, 19.995],
#                          'penalty': ['l1', 'l2', 'elasticnet'],
#                          'solver': ['lbfgs', 'newton-cg', 'sag', 'saga']},
#              verbose=3)

# %%
grid.fit(x_train, y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV 1/5] END ...C=19.99, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END ...C=19.99, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 3/5] END ...C=19.99, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 4/5] END ...C=19.99, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 5/5] END ...C=19.99, penalty=l1, solver=lbfgs;, score=nan total time=   0.0s
# [CV 1/5] END C=19.99, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 2/5] END C=19.99, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 3/5] END C=19.99, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 4/5] END C=19.99, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 5/5] END C=19.99, penalty=l1, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END .....C=19.99, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END .....C=19.99, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END .....C=19.99, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END .....C=19.99, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END .....C=19.99, penalty=l1, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END ..C=19.99, penalty=l1, solver=saga;, score=0.953 total time=   0.1s
# [CV 2/5] END ..C=19.99, penalty=l1, solver=saga;, score=0.947 total time=   0.1s
# [CV 3/5] END ..C=19.99, penalty=l1, solver=saga;, score=0.957 total time=   0.1s
# [CV 4/5] END ..C=19.99, penalty=l1, solver=saga;, score=0.957 total time=   0.1s
# [CV 5/5] END ..C=19.99, penalty=l1, solver=saga;, score=0.931 total time=   0.1s
# [CV 1/5] END .C=19.99, penalty=l2, solver=lbfgs;, score=0.960 total time=   0.0s
# [CV 2/5] END .C=19.99, penalty=l2, solver=lbfgs;, score=0.950 total time=   0.0s
# [CV 3/5] END .C=19.99, penalty=l2, solver=lbfgs;, score=0.960 total time=   0.0s
# [CV 4/5] END .C=19.99, penalty=l2, solver=lbfgs;, score=0.963 total time=   0.0s
# [CV 5/5] END .C=19.99, penalty=l2, solver=lbfgs;, score=0.941 total time=   0.0s
# [CV 1/5] END C=19.99, penalty=l2, solver=newton-cg;, score=0.963 total time=   0.1s
# [CV 2/5] END C=19.99, penalty=l2, solver=newton-cg;, score=0.949 total time=   0.0s
# [CV 3/5] END C=19.99, penalty=l2, solver=newton-cg;, score=0.964 total time=   0.0s
# [CV 4/5] END C=19.99, penalty=l2, solver=newton-cg;, score=0.965 total time=   0.0s
# [CV 5/5] END C=19.99, penalty=l2, solver=newton-cg;, score=0.940 total time=   0.0s
# [CV 1/5] END ...C=19.99, penalty=l2, solver=sag;, score=0.953 total time=   0.0s
# [CV 2/5] END ...C=19.99, penalty=l2, solver=sag;, score=0.942 total time=   0.0s
# [CV 3/5] END ...C=19.99, penalty=l2, solver=sag;, score=0.960 total time=   0.0s
# [CV 4/5] END ...C=19.99, penalty=l2, solver=sag;, score=0.953 total time=   0.0s
# [CV 5/5] END ...C=19.99, penalty=l2, solver=sag;, score=0.932 total time=   0.0s
# [CV 1/5] END ..C=19.99, penalty=l2, solver=saga;, score=0.953 total time=   0.0s
# [CV 2/5] END ..C=19.99, penalty=l2, solver=saga;, score=0.947 total time=   0.0s
# [CV 3/5] END ..C=19.99, penalty=l2, solver=saga;, score=0.957 total time=   0.1s
# [CV 4/5] END ..C=19.99, penalty=l2, solver=saga;, score=0.957 total time=   0.1s
# [CV 5/5] END ..C=19.99, penalty=l2, solver=saga;, score=0.931 total time=   0.1s
# [CV 1/5] END C=19.99, penalty=elasticnet, solver=lbfgs;, score=nan total time=   0.0s
# [CV 2/5] END C
penalty=elasticnet, solver=newton-cg;, score=nan total time=   0.0s
# [CV 1/5] END C=19.995, penalty=elasticnet, solver=sag;, score=nan total time=   0.0s
# [CV 2/5] END C=19.995, penalty=elasticnet, solver=sag;, score=nan total time=   0.0s
# [CV 3/5] END C=19.995, penalty=elasticnet, solver=sag;, score=nan total time=   0.0s
# [CV 4/5] END C=19.995, penalty=elasticnet, solver=sag;, score=nan total time=   0.0s
# [CV 5/5] END C=19.995, penalty=elasticnet, solver=sag;, score=nan total time=   0.0s
# [CV 1/5] END C=19.995, penalty=elasticnet, solver=saga;, score=nan total time=   0.0s
# [CV 2/5] END C=19.995, penalty=elasticnet, solver=saga;, score=nan total time=   0.0s
# [CV 3/5] END C=19.995, penalty=elasticnet, solver=saga;, score=nan total time=   0.0s
# [CV 4/5] END C=19.995, penalty=elasticnet, solver=saga;, score=nan total time=   0.0s
# [CV 5/5] END C=19.995, penalty=elasticnet, solver=saga;, score=nan total time=   0.0s
# GridSearchCV(cv=5, estimator=LogisticRegression(),
#              param_grid={'C': [19.99, 19.999, 19.995],
#                          'penalty': ['l1', 'l2', 'elasticnet'],
#                          'solver': ['lbfgs', 'newton-cg', 'sag', 'saga']},
#              verbose=3)

# %%
grid.best_params_
# Out:
# {'C': 19.995, 'penalty': 'l2', 'solver': 'newton-cg'}

# %%
grid.best_score_
# Out:
# np.float64(0.9565588226656342)

# %%
best_model = grid.best_estimator_
y_predicted = best_model.predict(x_test)
y_predicted
# Out:
# array([0, 0, 0, ..., 0, 0, 1])

# %%
accuracy_score(y_test, y_predicted) * 100
# Out:
# 96.22641509433963

# %%
from sklearn.metrics import roc_curve, auc
y_pred_prob = grid.predict_proba(x_test)[:,1]
y_pred_prob
# Out:
# array([1.22012225e-10, 1.42250292e-01, 4.79780295e-01, ...,
#        2.53947971e-01, 9.31023120e-03, 9.99997955e-01])

# %%
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
def reports():
    print(f"Thresholds : \n{thresholds}\n")
    print(f"False Positive Rate : \n{fpr}n")
    print(f"True Positive Rate : \n{tpr}")

# %%
reports()
# Out:
# Thresholds :
# [           inf 1.00000000e+00 9.99679728e-01 9.99675671e-01
#  9.99666349e-01 9.99661729e-01 9.99560310e-01 9.99555362e-01
#  9.99541412e-01 9.99530435e-01 9.99498264e-01 9.98307797e-01
#  9.98266112e-01 9.98199957e-01 8.70806724e-01 8.69051768e-01
#  8.09511114e-01 8.08960061e-01 7.83160807e-01 7.82863713e-01
#  7.80179907e-01 7.75621873e-01 7.60112087e-01 7.55256594e-01
#  7.37289834e-01 7.37104614e-01 7.29047734e-01 7.26697855e-01
#  6.99217519e-01 6.96125808e-01 6.94540383e-01 6.93620239e-01
#  6.38377734e-01 6.23340743e-01 6.19723704e-01 6.18337629e-01
#  6.17249777e-01 6.17089873e-01 6.12118533e-01 6.09903550e-01
#  6.05788104e-01 6.03205517e-01 5.90345868e-01 5.78441959e-01
#  5.73913005e-01 5.71583180e-01 5.57504750e-01 5.56024679e-01
#  5.55777662e-01 5.52557643e-01 5.50149588e-01 5.47040476e-01
#  5.32577058e-01 5.29593508e-01 5.28463335e-01 5.19728411e-01
#  5.09914718e-01 4.99461628e-01 4.86859798e-01 4.86550329e-01
#  4.81329121e-01 4.80491347e-01 4.79374989e-01 4.73489492e-01
#  4.70828356e-01 4.59343186e-01 4.56935149e-01 4.37426780e-01
#  4.36482277e-01 4.27886083e-01 4.19304304e-01 4.04022781e-01
#  4.03850355e-01 3.87246928e-01 3.82061672e-01 3.79253189e-01
#  3.77293762e-01 3.49371187e-01 3.45986317e-01 3.42469771e-01
#  3.37748415e-01 3.35679283e-01 3.32739117e-01 3.13633600e-01
#  3.12925616e-01 3.03920459e-01 3.00093501e-01 2.99628096e-01
#  2.98038482e-01 2.89629305e-01 2.86089779e-01 2.72798094e-01
#  2.68039553e-01 2.60610605e-01 2.60468172e-01 2.55601193e-01
#  2.53947971e-01 2.52040315e-01 2.50186392e-01 2.32341279e-01
#  2.30149008e-01 2.19988046e-01 2.12033504e-01 2.05205291e-01
#  2.01556192e-01 1.76170166e-01 1.73663790e-01 1.71995828e-01
fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
from sklearn import tree
plt.figure(figsize=(12,20))
tree.plot_tree(classifier, filled=True)
# Out:
# [Text(0.3076923076923077, 0.9375, 'x[8] <= 0.5\nentropy = 0.999\nsamples = 5686\nvalue = [2972.0, 2714.0]'),
#  Text(0.23076923076923078, 0.8125, 'entropy = 0.0\nsamples = 1193\nvalue = [0, 1193]'),
#  Text(0.2692307692307693, 0.875, 'True  '),
#  Text(0.38461538461538464, 0.8125, 'x[19] <= 1.5\nentropy = 0.923\nsamples = 4493\nvalue = [2972, 1521]'),
#  Text(0.34615384615384615, 0.875, '  False'),
#  Text(0.15384615384615385, 0.6875, 'x[4] <= 3.5\nentropy = 0.335\nsamples = 1178\nvalue = [73, 1105]'),
#  Text(0.07692307692307693, 0.5625, 'entropy = 0.0\nsamples = 1105\nvalue = [0, 1105]'),
#  Text(0.23076923076923078, 0.5625, 'entropy = 0.0\nsamples = 73\nvalue = [73, 0]'),
#  Text(0.6153846153846154, 0.6875, 'x[7] <= 0.5\nentropy = 0.545\nsamples = 3315\nvalue = [2899, 416]'),
#  Text(0.38461538461538464, 0.5625, 'x[19] <= 4.5\nentropy = 0.178\nsamples = 2792\nvalue = [2717, 75]'),
#  Text(0.3076923076923077, 0.4375, 'entropy = 0.0\nsamples = 2308\nvalue = [2308, 0]'),
#  Text(0.46153846153846156, 0.4375, 'x[10] <= 0.5\nentropy = 0.622\nsamples = 484\nvalue = [409, 75]'),
#  Text(0.38461538461538464, 0.3125, 'entropy = 0.0\nsamples = 373\nvalue = [373, 0]'),
#  Text(0.5384615384615384, 0.3125, 'x[21] <= 3.5\nentropy = 0.909\nsamples = 111\nvalue = [36, 75]'),
#  Text(0.46153846153846156, 0.1875, 'x[20] <= 4.5\nentropy = 0.337\nsamples = 80\nvalue = [5, 75]'),
#  Text(0.38461538461538464, 0.0625, 'entropy = 0.0\nsamples = 75\nvalue = [0, 75]'),
#  Text(0.5384615384615384, 0.0625, 'entropy = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(0.6153846153846154, 0.1875, 'entropy = 0.0\nsamples = 31\nvalue = [31, 0]'),
#  Text(0.8461538461538461, 0.5625, 'x[4] <= 5.5\nentropy = 0.932\nsamples = 523\nvalue = [182, 341]'),
#  Text(0.7692307692307693, 0.4375, 'x[20] <= 3.5\nentropy = 0.995\nsamples = 336\nvalue = [182, 154]'),
#  Text(0.6923076923076923, 0.3125, 'entropy = 0.0\nsamples = 78\nvalue = [0, 78]'),
#  Text(0.8461538461538461, 0.3125, 'x[21] <= 1.0\nentropy = 0.875\nsamples = 258\nvalue = [182, 76]'),
#  Text(0.7692307692307693, 0.1875, 'x[9] <= 0.5\nentropy = 1.0\nsamples = 152\nvalue = [76, 76]'),
#  Text(0.6923076923076923, 0.0625, 'entropy = 0.0\nsamples = 76\nvalue = [0, 76]'),
#  Text(0.8461538461538461, 0.0625, 'entropy = 0.0\nsamples = 76\nvalue = [76, 0]'),
#  Text(0.9230769230769231, 0.1875, 'entropy = 0.0\nsamples = 106\nvalue = [106, 0]'),
#  Text(0.9230769230769231, 0.4375, 'entropy = 0.0\nsamples = 187\nvalue = [0, 187]')]

# %%
y_predicted = classifier.predict(x_test)
y_predicted
# Out:
# array([0, 1, 1, ..., 1, 0, 1])

# %%
accuracy_score(y_test, y_predicted)
# Out:
# 1.0

# %%
print(classification_report(y_test, y_predicted))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00      1236
#            1       1.00      1.00      1.00      1202
#
#     accuracy                           1.00      2438
#    macro avg       1.00      1.00      1.00      2438
# weighted avg       1.00      1.00      1.00      2438

# %%
confusion_matrix(y_test, y_predicted)
# Out:
# array([[1236,    0],
#        [   0, 1202]])
